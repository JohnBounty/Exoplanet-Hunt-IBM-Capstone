# %% [markdown]
# # Exoplanet Hunt
#
# *This notebook*

# %% [markdown]
# ## Downloading data

# %%
# !kaggle datasets list -s Exoplanet
# Out:
# ref                                               title                             size  lastUpdated          downloadCount  voteCount  usabilityRating
# ------------------------------------------------  -------------------------------  -----  -------------------  -------------  ---------  ---------------
# mrisdal/open-exoplanet-catalogue                  Open Exoplanet Catalogue         123KB  2017-06-08 19:59:22           2668        125  0.8235294
# nasa/kepler-exoplanet-search-results              Kepler Exoplanet Search Results    1MB  2017-10-10 18:26:59           3423        183  0.8235294
# keplersmachines/kepler-labelled-time-series-data  Exoplanet Hunting in Deep Space   56MB  2017-04-12 16:34:18           6070        309  0.8235294
# eduardowoj/exoplanets-database                    Exoplanets Database              281KB  2018-02-28 20:56:05            791         42  0.8235294
# ...

# %%
# !kaggle datasets download keplersmachines/kepler-labelled-time-series-data
# Out:
# ...
#  97%|████████████████████████████████████▋ | 54.0M/55.9M [00:02<00:00, 20.3MB/s]
# 100%|██████████████████████████████████████| 55.9M/55.9M [00:02<00:00, 20.8MB/s]

# %%
# !unzip kepler-labelled-time-series-data.zip
# Out:
# Archive:  kepler-labelled-time-series-data.zip
#   inflating: exoTest.csv
#   inflating: exoTrain.csv

# %%
# !ls
# Out:
# Untitled.ipynb                       exoTrain.csv
# doc                                  kepler-labelled-time-series-data.zip
# exoTest.csv                          source

# %% [markdown]
# ## Settings

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pywt

# %% [markdown]
# ## Checking data out

# %%
df = pd.read_csv("exoTrain.csv")
df_test = pd.read_csv("exoTest.csv")

# %%
df.head()
# Out:
#    LABEL   FLUX.1   FLUX.2   FLUX.3   FLUX.4   FLUX.5   FLUX.6  FLUX.7  \
# 0      2    93.85    83.81    20.10   -26.98   -39.56  -124.71 -135.18
# 1      2   -38.88   -33.83   -58.54   -40.09   -79.31   -72.81  -86.55
# 2      2   532.64   535.92   513.73   496.92   456.45   466.00  464.50
# 3      2   326.52   347.39   302.35   298.13   317.74   312.70  322.33
# 4      2 -1107.21 -1112.59 -1118.95 -1095.10 -1057.55 -1034.48 -998.34
#
#     FLUX.8  FLUX.9    ...      FLUX.3188  FLUX.3189  FLUX.3190  FLUX.3191  \
# 0   -96.27  -79.89    ...         -78.07    -102.15    -102.15      25.13
# 1   -85.33  -83.97    ...          -3.28     -32.21     -32.21     -24.89
# 2   486.39  436.56    ...         -71.69      13.31      13.31     -29.89
# 3   311.31  312.42    ...           5.71      -3.73      -3.73      30.05
# 4 -1022.71 -989.57    ...        -594.37    -401.66    -401.66    -357.24
#
#    FLUX.3192  FLUX.3193  FLUX.3194  FLUX.3195  FLUX.3196  FLUX.3197
# ...

# %%
len(df)
# Out:
# 5087

# %%
len(df_test)
# Out:
# 570

# %%
one_star = np.array(df[df.LABEL == 2].iloc[1])
label = one_star[0]
one_star = one_star[1:]
other_star = np.array(df[df.LABEL == 1].iloc[1])[1:]
print(len(one_star))
# Out:
# 3197

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 5))

ax[0].set_title("Star system with exoplanet")
ax[0].plot(one_star)
ax[1].set_title("Star system without exoplanets")
ax[1].plot(other_star);

# %%
def plot_scalogram(time, signal, scales, 
                 waveletname = 'gaus1', 
                 cmap = 'plasma', 
                 title = 'Scalogram of a signal', 
                 ylabel = 'Scale', 
                 xlabel = 'Time'):
    
    dt = time[1] - time[0]
    coefficients, frequencies = pywt.cwt(signal, scales, waveletname, dt)

    fig = plt.figure(figsize=(15, 5))
    plt.title(title, fontsize=16)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    im = plt.imshow(coefficients, cmap)
    fig.colorbar(im, orientation="horizontal")

# %%
scales = np.arange(1, 1025)
time = np.arange(len(one_star))
plot_scalogram(time, one_star, scales, title="Exoplanetful system")

# %%
scales = np.arange(1, 1025)
time = np.arange(len(one_star))
plot_scalogram(time, other_star, scales, title="Exoplanetless system")
